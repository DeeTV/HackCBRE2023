# %% [markdown]
# <a href="https://colab.research.google.com/github/DeeTV/HackCBRE2023/blob/main/Copy_of_BigQuery_bquxjob_229b6f1c_18b218ccccb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'cbre-dashboard' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %%
pip install fuzzywuzzy

# %%
import pandas as pd
from fuzzywuzzy import fuzz
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Running this code will read results from your previous job

job1 = client.get_job('bquxjob_74f1d4c6_18b219808be') # Job ID inserted based on the query results selected to explore
users = job1.to_dataframe()
#users

# %% [markdown]
# # Initialize a BigQuery client
# client = bigquery.Client()
#
# # Initialize a dictionary to store names with Sr_No as keys
# name_dict = {}
#
# # Iterate over the DataFrame
# for index, row in users.iterrows():
#     sr_no = row['Sr_No']
#     name = row['Name']
#     name_dict[sr_no] = name
#
#     job2=client.get_job('bquxjob_229b6f1c_18b218ccccb') # Job ID inserted based on the query results selected to explore
#     data_x = job2.to_dataframe()
#     data_y=data_x[data_x[0] == name]
#     print(data_y)
#
# # Access the results for different Sr_No values
# for sr_no, results in name_dict.items():
#     for result in results:
#         print(f"Results for Sr_No {sr_no}: {result}")
#
# # You can access the results for each Name in the name_dict dictionary.

# %%
# Initialize a dictionary to store names with Sr_No as keys
name_dict = {}

# Iterate over the DataFrame
for index, row in users.iterrows():
    sr_no = row['Sr_No']
    name = row['Name']
    name_dict[sr_no] = name

    job2=client.get_job('bquxjob_229b6f1c_18b218ccccb') # Job ID inserted based on the query results selected to explore
    data_x = job2.to_dataframe()
    ### have to run the colab code here, have to match name to the first column on every table and then run the code
    data_y =  data_x.loc[(data_x[0]==name)]
    print(data_y)
    #print(name)






# Access names using Sr_No
#for sr_no, name in name_dict.items():
#    print(f"Sr_No: {sr_no}, Name: {name}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=cbre-dashboard:US:bquxjob_229b6f1c_18b218ccccb)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('bquxjob_229b6f1c_18b218ccccb') # Job ID inserted based on the query results selected to explore
print(job.query)
# Out:
# SELECT * FROM `cbre-dashboard.cbre_dataset.U1`

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job

job = client.get_job('bquxjob_229b6f1c_18b218ccccb') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results
# Out:
#                         Name            Insight_1           Insight_2  \
# 0                  Betty Lin               Leases        Renewal Rate
# 1                  Betty Lin               Leases            Expiring
# 2                  Gina Hahn               Leases           Occupancy
# 3                  Gina Hahn               Leases           Occupancy
# 4                  Gina Hahn               Leases            Expiring
# ...                      ...                  ...                 ...
# 3110      Derrick Stephenson  Tenant Satisfaction  Lease Satisfaction
# 3111      Jennifer Glenn DDS  Tenant Satisfaction  Amenities Feedback
# 3112   Mrs. Teresa Dorsey MD  Tenant Satisfaction  Lease Satisfaction
# 3113   Mrs. Teresa Dorsey MD  Tenant Satisfaction    Noise Complaints
# 3114  Miss Rebecca Maldonado  Tenant Satisfaction  Amenities Feedback
#
#                               Driver             Account Criticality  \
# ...

# %% [markdown]
# ## Show descriptive statistics using describe()
# Use the ```pandas DataFrame.describe()```
# [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
# to generate descriptive statistics. Descriptive statistics include those that
# summarize the central tendency, dispersion and shape of a dataset’s
# distribution, excluding ```NaN``` values. You may also use other Python methods
# to interact with your data.

# %%
results.describe()
